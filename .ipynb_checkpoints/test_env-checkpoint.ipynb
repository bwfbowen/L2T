# %%
from src.env import MultiODEnv
from src.operators import TwoOptOperator, ExchangeOperator
# Out:
# /usr/local/anaconda3/envs/miniconda3/lib/python3.10/site-packages/gymnasium/envs/registration.py:604: UserWarning: WARN: plugin: shimmy.registration:register_gymnasium_envs raised Traceback (most recent call last):
#   File "/usr/local/anaconda3/envs/miniconda3/lib/python3.10/site-packages/gymnasium/envs/registration.py", line 602, in load_plugin_envs
#     fn()
#   File "/usr/local/anaconda3/envs/miniconda3/lib/python3.10/site-packages/shimmy/registration.py", line 262, in register_gymnasium_envs
#     _register_dm_control_envs()
#   File "/usr/local/anaconda3/envs/miniconda3/lib/python3.10/site-packages/shimmy/registration.py", line 26, in _register_dm_control_envs
#     from shimmy.dm_control_compatibility import DmControlCompatibilityV0
#   File "/usr/local/anaconda3/envs/miniconda3/lib/python3.10/site-packages/shimmy/dm_control_compatibility.py", line 18, in <module>
#     from gymnasium.envs.mujoco.mujoco_rendering import MujocoRenderer
#   File "/usr/local/anaconda3/envs/miniconda3/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py", line 7, in <module>
#     import imageio
# ModuleNotFoundError: No module named 'imageio'
#
#   logger.warn(f"plugin: {plugin.value} raised {traceback.format_exc()}")

# %%
env = MultiODEnv(num_O=8, num_taxi=1, seed=2)

# %%
sol, infos = env.reset()
fig = env.render()

# %%
next_sol, r, d, infos = env.step(2)
fig = env.render()

# %%
path = env.solution.paths[0]

# %%
path.block_dict
# Out:
# {0: SliceableDeque([Node(node_id=5, OD_type=0, seq_id=2, block_id=0, in_block_seq_id=0, block_OD=0),
#                  Node(node_id=7, OD_type=0, seq_id=3, block_id=0, in_block_seq_id=1, block_OD=0),
#                  Node(node_id=3, OD_type=0, seq_id=4, block_id=0, in_block_seq_id=2, block_OD=0),
#                  Node(node_id=6, OD_type=0, seq_id=5, block_id=0, in_block_seq_id=3, block_OD=0)]),
#  6: SliceableDeque([Node(node_id=9, OD_type=0, seq_id=10, block_id=6, in_block_seq_id=0, block_OD=0),
#                  Node(node_id=8, OD_type=0, seq_id=11, block_id=6, in_block_seq_id=1, block_OD=0)]),
#  7: SliceableDeque([Node(node_id=16, OD_type=1, seq_id=12, block_id=7, in_block_seq_id=0, block_OD=1),
#                  Node(node_id=17, OD_type=1, seq_id=13, block_id=7, in_block_seq_id=1, block_OD=1)]),
#  12: SliceableDeque([Node(node_id=14, OD_type=1, seq_id=6, block_id=12, in_block_seq_id=0, block_OD=1)]),
#  13: SliceableDeque([Node(node_id=13, OD_type=1, seq_id=8, block_id=13, in_block_seq_id=0, block_OD=1),
#                  Node(node_id=11, OD_type=1, seq_id=9, block_id=13, in_block_seq_id=1, block_OD=1)]),
#  14: SliceableDeque([Node(node_id=4, OD_type=0, seq_id=7, block_id=14, in_block_seq_id=0, block_OD=0)]),
#  15: SliceableDeque([Node(node_id=15, OD_type=1, seq_id=15, block_id=15, in_block_seq_id=0, block_OD=1),
#                  Node(node_id=10, OD_type=1, seq_id=16, block_id=15, in_block_seq_id=1, block_OD=1),
#                  Node(node_id=12, OD_type=1, seq_id=17, block_id=15, in_block_seq_id=2, block_OD=1)]),
#  16: SliceableDeque([Node(node_id=2, OD_type=0, seq_id=14, block_id=16, in_block_seq_id=0, block_OD=0)])}

# %%
path.seq_dict
# Out:
# {1: Node(node_id=1, OD_type=None, seq_id=1, block_id=None, in_block_seq_id=None, block_OD=None),
#  2: Node(node_id=5, OD_type=0, seq_id=2, block_id=0, in_block_seq_id=0, block_OD=0),
#  3: Node(node_id=7, OD_type=0, seq_id=3, block_id=0, in_block_seq_id=1, block_OD=0),
#  4: Node(node_id=3, OD_type=0, seq_id=4, block_id=0, in_block_seq_id=2, block_OD=0),
#  5: Node(node_id=6, OD_type=0, seq_id=5, block_id=0, in_block_seq_id=3, block_OD=0),
#  6: Node(node_id=14, OD_type=1, seq_id=6, block_id=12, in_block_seq_id=0, block_OD=1),
#  7: Node(node_id=4, OD_type=0, seq_id=7, block_id=14, in_block_seq_id=0, block_OD=0),
#  8: Node(node_id=13, OD_type=1, seq_id=8, block_id=13, in_block_seq_id=0, block_OD=1),
#  9: Node(node_id=11, OD_type=1, seq_id=9, block_id=13, in_block_seq_id=1, block_OD=1),
#  10: Node(node_id=9, OD_type=0, seq_id=10, block_id=6, in_block_seq_id=0, block_OD=0),
#  11: Node(node_id=8, OD_type=0, seq_id=11, block_id=6, in_block_seq_id=1, block_OD=0),
#  12: Node(node_id=16, OD_type=1, seq_id=12, block_id=7, in_block_seq_id=0, block_OD=1),
#  13: Node(node_id=17, OD_type=1, seq_id=13, block_id=7, in_block_seq_id=1, block_OD=1),
#  14: Node(node_id=2, OD_type=0, seq_id=14, block_id=16, in_block_seq_id=0, block_OD=0),
#  15: Node(node_id=15, OD_type=1, seq_id=15, block_id=15, in_block_seq_id=0, block_OD=1),
#  16: Node(node_id=10, OD_type=1, seq_id=16, block_id=15, in_block_seq_id=1, block_OD=1),
#  17: Node(node_id=12, OD_type=1, seq_id=17, block_id=15, in_block_seq_id=2, block_OD=1)}

# %%
path.get_by_seq_id(3).next_node
# Out:
# Node(node_id=3, OD_type=0, seq_id=4, block_id=0, in_block_seq_id=2, block_OD=0)

# %%
path.D_blocks
# Out:
# [7, 12, 13, 15]

# %%
path.O_blocks
# Out:
# [0, 6, 14, 16]

# %%
path.D_blocks
# Out:
# [7, 12, 13, 15]

# %%
path.O_blocks
# Out:
# [0, 6, 14, 16]

# %%
env

# %%
env.render()
