# %%
import numpy as np
from src.env import MultiODEnv

# %%
env = MultiODEnv(num_O=8, num_taxi=1, seed=1)

# %%
obs, info = env.reset()

# %%
obs['problem'].shape
# Out:
# (4,)

# %%
len(env.action_dict)
# Out:
# 21

# %%
next_obs, reward, done, infos = env.step(11)
fig = env.render()
print(env.problem.calc_cost(env.solution))
print(env.problem.is_feasible(env.solution))
# Out:
# 5.384807315996398
# True
