# %%
from src.env import MultiODEnv

# %%
env = MultiODEnv(num_O=8, num_taxi=1, seed=1)

# %%
obs, info = env.reset()

# %%
obs.shape
# Out:
# (1, 19)

# %%
#o->d.next->o.next
# cross two blocks, block.prev for loop, reverse, 
# reverse some; cross-block 2-opt

# %%
next_obs, reward, done, infos = env.step(2)
fig = env.render()
print(env.problem.calc_cost(env.solution))
print(env.problem.is_feasible(env.solution))
# Out:
# 6.975501523492436
# True
